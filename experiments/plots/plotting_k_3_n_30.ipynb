randomMsmMdian = []
randomBucketsMsmMdian = [-0.33371, -0.34077, -0.31464, -0.34209, -0.25006, -0.12422, -0.066005, -0.032841, -0.052163, -0.11884, -0.14803, -0.073956, 0.03704, 0.13759, 0.14834, 0.32768, 0.44863, 0.58289, 0.71932, 0.9027, 1.0301, 1.1144, 1.2388, 1.3994]
avereagebuckets = [-0.34077, -0.34077, -0.35879, -0.35731, -0.36415, -0.32538, -0.25006, -0.12806, -0.074725, -0.092605, -0.085618, -0.085618, -0.096982, -0.11884, -0.12321, -0.073956, 0.030384, 0.17114, 0.32918, 0.32768, 0.33239, 0.55452, 0.5744, 0.66836, 0.87944, 0.97571, 1.0163, 1.1673, 1.2388, 1.3994]
genericEA = [-0.32727, -0.35731, -0.34081, -0.22674, -0.12806, -0.074725, -0.066005, 0.030384, 0.11954, 0.17114, 0.17114, 0.17114, -0.066005, -0.066005, -0.066005, -0.096982, -0.1123, -0.14037, -0.13473, -0.054362, 0.031797, 0.13759, 0.3249, 0.3249, 0.43298, 0.5744, 0.66836, 0.87944, 1.0163, 1.2026]
bucketsea = [-0.32727, -0.35731, -0.35879, -0.33733, -0.32538, -0.34081, -0.2209, -0.2209, -0.12806, -0.085618, -0.066005, -0.032841, -0.058158, -0.11884, -0.13473, -0.054362, 0.031797, 0.13759, 0.13759, 0.32918, 0.32918, 0.43298, 0.5744, 0.66456, 0.76934, 0.9027, 1.0301, 1.1515, 1.2388, 1.3983]

median = [-0.33371, -0.35731, -0.35879, -0.33733, -0.32538, -0.34081, -0.22674, -0.12806, -0.085618, -0.066005, -0.032841, -0.066248, -0.11884, -0.14803, -0.054362, 0.031797, 0.13759, 0.32918, 0.43298, 0.5744, 0.66456, 0.76934, 0.9027, 1.0301, 1.1515, 1.2388, 1.3983]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', label="buckets", linestyle = 'dashed')
plt.plot(randomBucketsMsmMdian, 'green', label="random buckets", linestyle = 'dashdot')
plt.plot(avereagebuckets, 'orange', label="average buckets", linestyle = 'dashdot')
plt.plot(genericEA, 'blue', label="generic EA", linestyle = 'dotted')
plt.plot(bucketsea, 'black', label="buckets EA", linestyle = 'dotted')
plt.legend(loc="upper right")
plt.show()

# %%
# oliveoil
bucketsMsnNedian = [0.94309, 0.91731, 0.89806, 0.88226, 0.86881, 0.8603, 0.86024, 0.87042, 0.88859, 0.91218, 0.93983, 0.97124, 1.0001, 1.0248, 1.0449, 1.0618, 1.0719, 1.0709, 1.052, 1.0154, 0.96098, 0.89343, 0.81564, 0.73837, 0.67544, 0.63224, 0.60396, 0.58121, 0.55625, 0.52902]
randomMsmMdian = []
randomBucketsMsmMdian = [0.9411, 0.91964, 0.90116, 0.88191, 0.86869, 0.86024, 0.87051, 0.88939, 0.91351, 0.94135, 0.97193, 0.99683, 1.0251, 1.0414, 1.0618, 1.0666, 1.052, 1.0154, 0.96294, 0.89343, 0.81564, 0.73685, 0.6787, 0.63079, 0.60396, 0.55625, 0.53071]
avereagebuckets = [0.94309, 0.91446, 0.89693, 0.88191, 0.87263, 0.8603, 0.86024, 0.87051, 0.88807, 0.91218, 0.94135, 0.96904, 1.0001, 1.0214, 1.0414, 1.0618, 1.0734, 1.0737, 1.0549, 1.0127, 0.96294, 0.89343, 0.81778, 0.73837, 0.67421, 0.63658, 0.60777, 0.58121, 0.55625, 0.52902]
genericEA = [0.94135, 0.94135, 0.94135, 0.94135, 0.91731, 0.89806, 0.88226, 0.86869, 0.86869, 0.8603, 0.86024, 0.87042, 0.88939, 0.89066, 0.89066, 0.88859, 0.88859, 0.88859, 0.91205, 0.91205, 0.91205, 0.93983, 0.97124, 1.0001, 1.0456, 1.0154, 0.96098, 0.89343, 0.81564, 0.67421]
bucketsea = [0.94309, 0.91731, 0.89806, 0.88226, 0.86881, 0.86024, 0.87042, 0.88859, 0.91218, 0.93983, 0.93983, 0.97124, 0.97124, 0.97124, 1.0001, 1.0248, 1.0449, 1.0618, 1.0719, 1.0709, 1.052, 1.0154, 0.96098, 0.89343, 0.89343, 0.81564, 0.73837, 0.67544, 0.63224, 0.53071]

median = [0.94309, 0.91731, 0.89806, 0.88226, 0.86881, 0.8603, 0.86024, 0.87042, 0.88859, 0.91218, 0.93983, 0.97124, 1.0001, 1.0248, 1.0449, 1.0618, 1.0719, 1.0709, 1.052, 1.0154, 0.96098, 0.89343, 0.81564, 0.73837, 0.67544, 0.63224, 0.60396, 0.58121, 0.55625, 0.52902]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', label="buckets", linestyle = 'dashed')
plt.plot(randomBucketsMsmMdian, 'green', label="random buckets", linestyle = 'dashdot')
plt.plot(avereagebuckets, 'orange', label="average buckets", linestyle = 'dashdot')
plt.plot(genericEA, 'blue', label="generic EA", linestyle = 'dotted')
plt.plot(bucketsea, 'black', label="buckets EA", linestyle = 'dotted')
plt.legend(loc="upper right")
plt.show()

# %%
# ecg200, 
bucketsMsnNedian = [0.55923, 0.55571, 0.46969, 0.38882, 0.47011, 0.5356, 0.6063, 0.65685, 0.68908, 0.59881, 0.54265, 0.12095, 0.3264, 0.47395, 0.59474, 0.65738, 0.65089, 0.57517, 0.4012, 0.34997, 0.14805, -0.033206, -0.11427, 0.12035, -0.2201, -0.15123, -0.077445, -0.097869, -0.13679, 0.17608]
randomMsmMdian = []
randomBucketsMsmMdian = [0.66442, 0.36957, 0.37732, 0.73207, 0.5356, 0.90071, 0.65685, 0.68908, 0.59881, 0.54777, 0.12095, 0.63063, 0.47395, 0.68632, 0.6982, 0.82678, 0.72174, 0.4012, 0.34997, 0.69523, -0.38664, -0.50751, -0.71666, -0.46044, -0.77079, -0.097869, 0.6103, 0.63889]
avereagebuckets = [0.44068, 0.72355, 0.36957, 0.36957, 0.5356, 0.47011, 0.25126, 0.6063, 0.9526, 0.69003, 0.58181, -0.16769, 0.63063, 0.66442, 0.59474, 0.68632, 0.65089, 0.57517, 0.69148, 0.34997, -0.033206, -0.033206, -0.11427, 0.12035, -0.46376, -0.2201, -0.097869, -0.097869, -0.13679, -0.13679]
genericEA = [0.55923, 0.55571, 0.46969, 0.38882, 0.47011, 0.5356, 0.6063, 0.65685, 0.68908, 0.59881, 0.54265, 0.12095, 0.3264, 0.47395, 0.59474, 0.65738, 0.65089, 0.57517, 0.4012, 0.34997, 0.14805, -0.033206, -0.11427, 0.12035, -0.2201, -0.15123, -0.077445, -0.097869, -0.13679, 0.17608]
bucketsea = [0.55923, 0.55571, 0.46969, 0.38882, 0.47011, 0.5356, 0.6063, 0.65685, 0.68908, 0.59881, 0.54265, 0.12095, 0.3264, 0.47395, 0.59474, 0.65738, 0.65089, 0.57517, 0.4012, 0.34997, 0.14805, -0.033206, -0.11427, 0.12035, -0.2201, -0.15123, -0.077445, -0.097869, -0.13679, 0.17608]

median = [0.55923, 0.55571, 0.46969, 0.38882, 0.47011, 0.5356, 0.6063, 0.65685, 0.68908, 0.59881, 0.54265, 0.12095, 0.3264, 0.47395, 0.59474, 0.65738, 0.65089, 0.57517, 0.4012, 0.34997, 0.14805, -0.033206, -0.11427, 0.12035, -0.2201, -0.15123, -0.077445, -0.097869, -0.13679, 0.17608]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', label="buckets", linestyle = 'dashed')
plt.plot(randomBucketsMsmMdian, 'green', label="random buckets", linestyle = 'dashdot')
plt.plot(avereagebuckets, 'orange', label="average buckets", linestyle = 'dashdot')
plt.plot(genericEA, 'blue', label="generic EA", linestyle = 'dotted')
plt.plot(bucketsea, 'black', label="buckets EA", linestyle = 'dotted')
plt.legend(loc="upper right")
plt.show()

# %%
# osuleaf
bucketsMsnNedian = [-0.16991, -0.18862, -0.18862, -0.021151, -0.021151, 0.40042, 0.45522, 0.3271, -0.43292, -0.43292, -0.53471, -0.71098, -0.80856, -0.83229, -0.98961, -0.99475, -1.0476, -0.90406]
randomMsmMdian = []
randomBucketsMsmMdian = [-0.16991, -0.23317, -0.29887, -0.38376, 0.062456, -0.077543, -0.18018, -0.31241, -0.26129, -0.43292, -0.53257, -0.48251, -0.49039, -0.66155, -0.73945, -0.78587, -0.98083, -1.1445, -0.90406]
avereagebuckets = [-0.16991, -0.23317, -0.29887, -0.18862, -0.38376, -0.10564, -0.077543, -0.151, 0.23069, 0.31594, -0.22838, -0.31241, 0.56771, 0.64814, 0.7634, 0.7634, -0.53257, -0.070995, -0.49039, -0.38811, -0.53471, -0.53471, -0.69595, -0.78587, -0.94147, -0.98083, -0.99475, -1.0476, -0.8864, -0.90406]
genericEA = [-0.34529, -0.34529, -0.27965, -0.18018, -0.10564, -0.021151, 0.062456, 0.14622, 0.23069, 0.28226, 0.155, 0.042818, -0.11652, -0.22668, -0.22668, -0.38811, -0.43292, -0.53471, -0.53471, -0.69595, -0.69595, -0.80856, -0.83229, -0.98083, -0.98961, -1.0945, -1.0945, -1.0476, -0.8864, -0.78587]
bucketsea = [1.6728, 1.6728, 1.5182, 1.3298, 1.192, 1.0593, 0.89309, 0.89309, 0.81305, 0.62775, 0.55327, 0.45522, 0.3271, 0.28226, 0.155, -0.070995, -0.070995, -0.22668, -0.38811, -0.53471, -0.53471, -0.69595, -0.69595, -0.78587, -0.83229, -0.94147, -0.98961, -1.0476, -1.0476, -0.8864]

median = [-0.23317, -0.34529, -0.27965, -0.18862, -0.077543, -0.070995, -0.22668, -0.38811, -0.53471, -0.66155, -0.73945, -0.80856, -0.87903, -0.98083, -0.99475, -1.0476, -0.90406]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', label="buckets", linestyle = 'dashed')
plt.plot(randomBucketsMsmMdian, 'green', label="random buckets", linestyle = 'dashdot')
plt.plot(avereagebuckets, 'orange', label="average buckets", linestyle = 'dashdot')
plt.plot(genericEA, 'blue', label="generic EA", linestyle = 'dotted')
plt.plot(bucketsea, 'black', label="buckets EA", linestyle = 'dotted')
plt.legend(loc="upper right")
plt.show()

# %%
# syntheticcontrol
bucketsMsnNedian = [-0.043934, -0.24302, 0.016406, 1.2286, 1.2286, -1.0134, -0.69236, 0.3497, -0.69916, 0.17318, 0.47339, -1.1331, -0.21466, -0.33874, -0.98063, 1.36, 0.66856, -0.24245, -0.55251, -1.1067, -0.60469, -0.60469, 1.3844, 0.71909]
randomMsmMdian = []
randomBucketsMsmMdian = [-0.24302, -1.0765, 0.32128, 0.75063, -1.0569, -0.8211, -1.336, -1.1331, 0.45842, -0.55154, 0.66856, 1.0054, -0.47445, -0.55251, -1.1067, -0.60469, 0.24213, -0.86658, 1.5268, 0.71909]
avereagebuckets = [-0.043934, -0.24302, 0.063543, 0.77621, 0.75063, -1.0134, -0.69236, 0.077386, -0.58886, -0.23914, -0.17278, -0.17278, -0.21466, -0.21466, -0.98063, -0.98063, -0.55154, 1.36, -0.98307, -0.98307, -0.47445, -0.64675, -0.27311, -0.27311, -1.0501, -0.60469, 0.24213, 0.24213, 1.3844, 0.94259]
genericEA = [-0.043934, -0.24302, 0.016406, 1.2286, 1.2423, 0.77621, -1.0134, -1.0318, -0.36321, 0.17318, -0.17278, 0.3497, 0.45842, -0.70278, -0.33874, -1.3896, -1.6279, -1.1271, 0.27302, -0.83746, 0.45842, 0.81411, 0.90384, -0.47445, -0.56294, -1.0946, 0.90208, 0.32962, 1.3999, 0.71909]
bucketsea = [-0.043934, -0.24302, 0.016406, 0.016406, 1.2423, 0.77621, 0.77621, -1.0134, -1.0318, -0.56294, 0.17318, -0.17278, 0.45842, 0.45842, -0.70278, -0.33874, -1.4316, -1.1271, 0.27302, -0.83746, 0.34063, 0.34063, 0.90384, -0.47445, -0.55251, -1.0501, 0.90208, 0.32962, 1.3999, 0.71909]

median = [-0.043934, -1.0134, 0.016406, 0.17318, 0.077386, 0.3497, -1.0765, -0.33874, -1.6279, -1.0765, -0.56294, 0.45842, -0.69916, 1.0054, -0.47445, -0.27311, -0.64675, -1.0765, -0.97035, -1.0501, 0.27302, 0.24213, -0.60469, 1.3844, 0.71909]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', label="buckets", linestyle = 'dashed')
plt.plot(randomBucketsMsmMdian, 'green', label="random buckets", linestyle = 'dashdot')
plt.plot(avereagebuckets, 'orange', label="average buckets", linestyle = 'dashdot')
plt.plot(genericEA, 'blue', label="generic EA", linestyle = 'dotted')
plt.plot(bucketsea, 'black', label="buckets EA", linestyle = 'dotted')
plt.legend(loc="upper right")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
# adiac, 
bucketsMsnNedian = [1.7723, 1.8009, 1.7913, 1.7186, 1.6605, 1.5752, 1.4822, 1.3767, 1.2733, 1.1714, 1.0626, 0.97446, 0.87981, 0.77515, 0.68622, 0.58807, 0.48701]
randomMsmMdian = []
randomBucketsMsmMdian = [1.7723, 1.8291, 1.7913, 1.7873, 1.6605, 1.534, 1.5447, 1.3977, 1.2733, 1.183, 1.0626, 0.99927, 0.91134, 0.87612, 0.68622, 0.64646, 0.4587]
avereagebuckets = [1.8009, 1.8258, 1.8003, 1.7122, 1.6614, 1.5752, 1.4822, 1.3767, 1.3079, 1.2181, 1.0758, 1.0488, 0.91134, 0.83545, 0.70682, 0.68622, 0.48701]
genericEA = [1.7895, 1.8258, 1.8003, 1.7723, 1.685, 1.5752, 1.4822, 1.3977, 1.2733, 1.183, 1.0626, 0.99927, 0.91134, 0.82105, 0.74551, 0.62288, 0.55178]
bucketsea = [1.7873, 1.8279, 1.8003, 1.7557, 1.6935, 1.5752, 1.4822, 1.3977, 1.2733, 1.1714, 1.0758, 0.99927, 0.91134, 0.79079, 0.68622, 0.62288, 0.48701]

median = [1.7723, 1.8009, 1.7913, 1.7186, 1.6605, 1.5752, 1.4822, 1.3767, 1.2733, 1.1714, 1.0626, 0.97446, 0.87981, 0.77515, 0.68622, 0.58807, 0.48701]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', alpha=0.3, label="buckets")
plt.plot(randomBucketsMsmMdian, 'green', alpha=0.3, label="random buckets")
plt.plot(avereagebuckets, 'orange', alpha=0.3, label="average buckets")
plt.plot(genericEA, 'blue', alpha=0.3, label="generic EA")
plt.plot(bucketsea, 'black', alpha=0.3, label="buckets EA")
plt.legend(loc="upper right")
plt.show()

# %%
# coffee,
bucketsMsnNedian = [-0.58432, -0.60725, -0.79168, -0.9559, -1.0843, -1.1295, -1.1908, -1.2334, -1.2543, -1.2605, -1.3264, -1.3715, -1.4345, -1.5372, -1.6144]
randomMsmMdian = []
randomBucketsMsmMdian = [-0.58432, -0.79168, -0.9559, -1.0885, -1.1908, -1.2267, -1.2768, -1.291, -1.2985, -1.3715, -1.4345, -1.5154, -1.6096]
avereagebuckets = [-0.43789, -0.66327, -0.91374, -0.9559, -1.1847, -1.1908, -1.2334, -1.2764, -1.2216, -1.2113, -1.2985, -1.2718, -1.243, -1.3074, -1.4816, -1.5154, -1.5936]
genericEA = [-0.58432, -0.60725, -0.79168, -0.9559, -1.0843, -1.0938, -1.1847, -1.2362, -1.2543, -1.2764, -1.2768, -1.2768, -1.3067, -1.3715, -1.4345, -1.5087, -1.6096]
bucketsea = [-0.45843, -0.60725, -0.77932, -0.9559, -1.0843, -1.0885, -1.1847, -1.2368, -1.2543, -1.2768, -1.2768, -1.2768, -1.3074, -1.3693, -1.4345, -1.5087, -1.6096]

median = [-0.58432, -0.60725, -0.79168, -0.9559, -1.0843, -1.1701, -1.2368, -1.2543, -1.3074, -1.3715, -1.4441, -1.5154, -1.6096]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', alpha=0.3, label="buckets")
plt.plot(randomBucketsMsmMdian, 'green', alpha=0.3, label="random buckets")
plt.plot(avereagebuckets, 'orange', alpha=0.3, label="average buckets")
plt.plot(genericEA, 'blue', alpha=0.3, label="generic EA")
plt.plot(bucketsea, 'black', alpha=0.3, label="buckets EA")
plt.legend(loc="upper right")
plt.show()

# %%
# oliveoil
bucketsMsnNedian = [-0.22767, -0.20973, -0.19637, -0.18239, -0.17271, -0.16556, -0.16556, -0.16948, -0.17424, -0.18157, -0.18702, -0.18961, -0.19008, -0.18619, -0.17996, -0.17439, -0.17139]
randomMsmMdian = []
randomBucketsMsmMdian = [-0.23348, -0.20921, -0.19637, -0.18826, -0.16952, -0.16363, -0.16948, -0.17116, -0.17526, -0.18562, -0.18958, -0.18911, -0.18619, -0.17571, -0.1716, -0.16801]
avereagebuckets = [-0.22767, -0.20973, -0.19337, -0.18239, -0.17271, -0.1697, -0.16766, -0.16948, -0.18157, -0.17878, -0.18677, -0.18961, -0.19008, -0.19008, -0.17571, -0.17074, -0.16867]
genericEA = [-0.22767, -0.20921, -0.19532, -0.18375, -0.17271, -0.16556, -0.16363, -0.16767, -0.17526, -0.18157, -0.18677, -0.18961, -0.18961, -0.18344, -0.17996, -0.1716, -0.1697]
bucketsea = [-0.22767, -0.20973, -0.19475, -0.18375, -0.17271, -0.16556, -0.16556, -0.16767, -0.17424, -0.18227, -0.18677, -0.18961, -0.19008, -0.18562, -0.17668, -0.1716, -0.17074]

median = [-0.22767, -0.20973, -0.19637, -0.18375, -0.17271, -0.16556, -0.16556, -0.16767, -0.17526, -0.18227, -0.18702, -0.18961, -0.19008, -0.18619, -0.17996, -0.1716, -0.17139]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', alpha=0.3, label="buckets")
plt.plot(randomBucketsMsmMdian, 'green', alpha=0.3, label="random buckets")
plt.plot(avereagebuckets, 'orange', alpha=0.3, label="average buckets")
plt.plot(genericEA, 'blue', alpha=0.3, label="generic EA")
plt.plot(bucketsea, 'black', alpha=0.3, label="buckets EA")
plt.legend(loc="upper right")
plt.show()

# %%
# ecg200, 
bucketsMsnNedian = [0.93377, 0.38028, -0.29678, -0.51393, -0.3697, -0.43356, -0.72908, -0.90694, -0.87096, -1.0602, -1.198, -0.9816, -1.2725, -1.2874, -1.0855, -1.5397, -1.2298]
randomMsmMdian = []
randomBucketsMsmMdian = [1.1682, 0.38028, -0.022363, -0.51393, -0.25564, -0.79879, -0.72908, -0.41801, -0.31916, -0.26038, -0.35036, -0.9816, -0.88184, -1.2874, -0.88365, -1.1539, -1.0361]
avereagebuckets = [1.0088, 0.7014, -0.022363, -0.51393, -0.11827, -0.3697, -0.72908, -0.41801, -0.87096, -0.31916, -0.68248, -0.68248, -1.2725, -0.84332, -1.5744, -1.5744, -1.0553]
genericEA = [0.93377, 0.49996, -0.11827, -0.51393, -0.35036, -0.41801, -0.68248, -0.68248, -0.31916, -0.68248, -1.0559, -0.79879, -0.88184, -0.90694, -1.0855, -1.3466, -1.0553]
bucketsea = [1.0088, 0.49996, -0.022363, -0.25564, -0.28783, -0.28783, -0.3697, -0.72908, -0.87096, -0.68248, -0.41773, -0.9816, -0.88184, -1.198, -1.0251, -1.2298, -1.2298]

median = [0.93377, 0.49996, -0.29678, -0.51393, -0.3697, -0.68604, -0.72908, -0.90694, -0.87096, -1.0327, -1.198, -0.9816, -1.0251, -1.2874, -1.0855, -1.5397, -1.2298]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', alpha=0.3, label="buckets")
plt.plot(randomBucketsMsmMdian, 'green', alpha=0.3, label="random buckets")
plt.plot(avereagebuckets, 'orange', alpha=0.3, label="average buckets")
plt.plot(genericEA, 'blue', alpha=0.3, label="generic EA")
plt.plot(bucketsea, 'black', alpha=0.3, label="buckets EA")
plt.legend(loc="upper right")
plt.show()

# %%
# osuleaf
bucketsMsnNedian = [0.098279, -0.13934, -0.32431, -0.56598]
randomMsmMdian = []
randomBucketsMsmMdian = [-0.092109, -0.098762, -0.13934, -0.19662, -0.30991, -0.35014, -0.45232, -0.56598, -0.63079]
avereagebuckets = [0.22511, -0.079128, 0.028448, 0.028448, -0.13514, -0.13514, -0.19662, -0.19662, -0.25124, -0.30991, 0.009801, 0.10134, -0.45232, -0.39816, -0.41833, -0.56598, -0.63079]
genericEA = [0.028448, 0.028448, 0.028448, -0.089483, -0.098762, -0.098762, -0.13514, -0.13934, -0.17208, -0.19662, -0.19662, -0.30991, -0.32431, -0.35014, -0.41833, -0.45232, -0.50755]
bucketsea = [0.098279, 0.098279, 0.092688, 0.092688, 0.092688, -0.098762, -0.098762, -0.13514, -0.13934, -0.17208, -0.19662, -0.25124, -0.30991, -0.32431, -0.41833, -0.41833, -0.50755]

median = [-0.079128, -0.089483, -0.19445, -0.30991, -0.41833, -0.50755]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', alpha=0.3, label="buckets")
plt.plot(randomBucketsMsmMdian, 'green', alpha=0.3, label="random buckets")
plt.plot(avereagebuckets, 'orange', alpha=0.3, label="average buckets")
plt.plot(genericEA, 'blue', alpha=0.3, label="generic EA")
plt.plot(bucketsea, 'black', alpha=0.3, label="buckets EA")
plt.legend(loc="upper right")
plt.show()

# %%
# syntheticcontrol
bucketsMsnNedian = [0.47339, -1.1331, -0.21466, 0.28137, -0.10539, 1.0054, -0.47445, -0.55251, -1.0501, 0.32962]
randomMsmMdian = []
randomBucketsMsmMdian = [0.47339, -0.70278, -0.33874, 0.28137, -0.19754, 1.0054, -0.47445, -0.55251, -1.0501, -0.026563, -0.26709]
avereagebuckets = [0.47339, 0.82061, -0.11912, -0.11912, 0.033749, 0.033749, -0.10539, -0.10539, 0.27302, -0.98307, 0.34063, -0.27311, 0.074653, 0.074653, -0.60469, 0.24213, -0.86658]
genericEA = [0.47339, 0.52906, -0.70278, -0.24245, -0.24245, -0.19754, -0.21466, 0.50763, 0.50763, -0.83746, 0.033749, -0.17278, 0.34063, 0.27302, -0.3778, -0.3778, -0.26709]
bucketsea = [-0.17278, -0.17278, 0.47339, 0.47339, -0.55154, -0.55154, -0.55154, 0.033749, -0.64675, -0.98307, -0.98307, -0.98307, 0.11887, -0.37866, -0.3778, -0.60469, 0.32962]

median = [0.47339, -0.70278, -0.98063, 0.27302, -0.21466, 0.63042, 0.90384, -0.30474, -0.27311, -0.55251, -0.98307, 0.074653]

plt.plot(median, 'r', label="Exact")
plt.plot(bucketsMsnNedian, 'magenta', alpha=0.3, label="buckets")
plt.plot(randomBucketsMsmMdian, 'green', alpha=0.3, label="random buckets")
plt.plot(avereagebuckets, 'orange', alpha=0.3, label="average buckets")
plt.plot(genericEA, 'blue', alpha=0.3, label="generic EA")
plt.plot(bucketsea, 'black', alpha=0.3, label="buckets EA")
plt.legend(loc="upper right")
plt.show()
